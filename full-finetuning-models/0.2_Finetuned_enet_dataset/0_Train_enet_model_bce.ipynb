# %%
# Train E-Net on Quinn Dataset
# !python train_enet_BCE.py --experiment_name "dataset2_enet_model_bce" --data_path "/home/sebastian/codes/SensoryCity_working/0_classifier/Split"
# Out:
# ...
# Validation: 100%|███████████████████████████████| 14/14 [00:04<00:00,  3.45it/s]
# Epoch [1/65], Train Loss: 0.3395, Train Acc: 0.5942, Val Loss: 0.3110, Val Acc: 0.6859, Val F1: 0.6799
# ...
# Validation: 100%|███████████████████████████████| 14/14 [00:04<00:00,  3.46it/s]
# Epoch [2/65], Train Loss: 0.2939, Train Acc: 0.6606, Val Loss: 0.2632, Val Acc: 0.7341, Val F1: 0.7303
# ...
# Validation: 100%|███████████████████████████████| 14/14 [00:04<00:00,  3.37it/s]
# Epoch [3/65], Train Loss: 0.2802, Train Acc: 0.6766, Val Loss: 0.2599, Val Acc: 0.7059, Val F1: 0.7051
# ...
# Validation: 100%|███████████████████████████████| 14/14 [00:04<00:00,  3.36it/s]
# Epoch [4/65], Train Loss: 0.2687, Train Acc: 0.6931, Val Loss: 0.2593, Val Acc: 0.7282, Val F1: 0.7229
# ...
# Validation: 100%|███████████████████████████████| 14/14 [00:04<00:00,  3.50it/s]
# Epoch [5/65], Train Loss: 0.2579, Train Acc: 0.7165, Val Loss: 0.2681, Val Acc: 0.6976, Val F1: 0.6916
# ...

# %% [markdown]
# Epoch [26/65], Train Loss: 0.1628, Train Acc: 0.7941, Val Loss: 0.1764, Val Acc: 0.8019, Val F1: 0.8002
# Training Epoch 27/65: 100%|████████████████████████████████████████████████████████████████████████████████████████| 144/144 [01:40<00:00,  1.43it/s]
# Validation: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 17/17 [00:07<00:00,  2.28it/s]
# Epoch [27/65], Train Loss: 0.1552, Train Acc: 0.8019, Val Loss: 0.1836, Val Acc: 0.7933, Val F1: 0.7923
# Epoch [28/65], Train Loss: 0.1530, Train Acc: 0.8065, Val Loss: 0.1777, Val Acc: 0.8057, Val F1: 0.8037
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.70      0.81        50
#            1       0.81      0.78      0.80        50
#            2       1.00      0.40      0.57        50
#            3       0.86      0.74      0.80        50
#            4       0.53      0.96      0.69        50
#            5       0.68      0.86      0.76        50
#
#     accuracy                           0.74       300
#    macro avg       0.81      0.74      0.74       300
# weighted avg       0.81      0.74      0.74       300

# %%
# !python train_enet.py --experiment_name "enet_model" --data_path "/home/sebastian/codes/data/ABGQI_mel_spectrograms"
# Out:
# ...
# Validation: 100%|███████████████████████████████| 14/14 [00:04<00:00,  3.39it/s]
# Epoch [1/65], Train Loss: 0.9994, Train Acc: 0.5997, Val Loss: 0.9101, Val Acc: 0.6988, Val F1: 0.7001
# ...
# Validation: 100%|███████████████████████████████| 14/14 [00:04<00:00,  3.43it/s]
# Epoch [2/65], Train Loss: 0.8730, Train Acc: 0.6547, Val Loss: 0.7717, Val Acc: 0.7247, Val F1: 0.7185
# ...
# Validation: 100%|███████████████████████████████| 14/14 [00:04<00:00,  3.39it/s]
# Epoch [3/65], Train Loss: 0.8289, Train Acc: 0.6705, Val Loss: 0.7362, Val Acc: 0.7282, Val F1: 0.7232
# ...
# Validation: 100%|███████████████████████████████| 14/14 [00:04<00:00,  3.39it/s]
# Epoch [4/65], Train Loss: 0.7979, Train Acc: 0.6867, Val Loss: 0.7344, Val Acc: 0.7024, Val F1: 0.6950
# ...
# Validation: 100%|███████████████████████████████| 14/14 [00:04<00:00,  3.42it/s]
# Epoch [5/65], Train Loss: 0.7557, Train Acc: 0.7066, Val Loss: 0.7557, Val Acc: 0.7435, Val F1: 0.7389
# ...
