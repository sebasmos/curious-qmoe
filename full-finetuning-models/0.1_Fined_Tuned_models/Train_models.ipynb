# %% [markdown]
# # Quinn dataset:

# %%
EXPERIMENT_NAME = "dataset_quinn_BCE" # save here sigmoid predictions
DATASET = "/home/sebastian/codes/data/ABGQI_mel_spectrograms"

# %%
# !ls {DATASET}
# Out:
# merged	Pruebas_Rutas.csv  test  train	val

# %%
root = "/home/sebastian/codes/VE"
# !pip install -e {root}

# %%
pip list | grep VE
# Out:
# VE                            0.1                /home/sebastian/codes/VE_working
# Note: you may need to restart the kernel to use updated packages.

# %%
# CUDA_VISIBLE_DEVICES=1 python train.py --accum_iter 4 --batch_size 64 \
#     --epochs 100 --blr 5e-4 --layer_decay 0.65 --weight_decay 0.05 --drop_path 0.1 \
#     --mixup 0.8 --cutmix 1.0 --reprob 0.25 --dist_eval \
#     --data_path /home/sebastian/codes/data/ABGQI_mel_spectrograms --nb_classes 5 \
#     --output_dir EfficientNetb3 --lr 0.0001 --warmup_epochs 10 \
#     --input_size 300 --experiment_name dataset_quinn_BCE --training_mode

# !CUDA_VISIBLE_DEVICES=1 python train.py --accum_iter 4 --batch_size 64 \
    --epochs 100 --blr 5e-4 --layer_decay 0.65 --weight_decay 0.05 --drop_path 0.1 \
    --mixup 0.8 --cutmix 1.0 --reprob 0.25 --dist_eval \
    --data_path {DATASET} --nb_classes 5 \
    --output_dir EfficientNetb3 --lr 0.0001 --warmup_epochs 10 \
    --input_size 300 --experiment_name {EXPERIMENT_NAME} --training_mode
# Out:
# 2024-11-16 18:26:18.389529: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-16 18:26:18.389602: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-16 18:26:18.391199: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-16 18:26:18.397709: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !CUDA_VISIBLE_DEVICES=1 python train.py --accum_iter 4 --batch_size 64 \
    --epochs 100 --blr 5e-4 --layer_decay 0.65 --weight_decay 0.05 --drop_path 0.1 \
    --mixup 0.8 --cutmix 1.0 --reprob 0.25 --dist_eval \
    --data_path {DATASET} --nb_classes 5 \
    --resume /home/sebastian/codes/VE_working/0_Fined_Tuned_models/dataset_quinn_BCE/best_model.pth \
    --output_dir EfficientNetb3 --lr 0.0001 --warmup_epochs 10 \
    --input_size 300 --experiment_name {EXPERIMENT_NAME} --eval --file_name "test"
# Out:
# 2024-11-16 18:54:09.454336: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-16 18:54:09.454378: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-16 18:54:09.455668: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-16 18:54:09.460636: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# CUDA_VISIBLE_DEVICES=1 python train.py --accum_iter 4 --batch_size 64 --epochs 100 --blr 5e-4 --layer_decay 0.65 --weight_decay 0.05 --drop_path 0.1 --mixup 0.8 --cutmix 1.0 --reprob 0.25 --dist_eval --data_path "/home/sebastian/codes/data/ABGQI_mel_spectrograms" --nb_classes 5 --resume /home/sebastian/codes/VE_working/0_Fined_Tuned_models/BS_Pytorch_EPOCHS/model_weights.pth --output_dir EfficientNetb3 --lr 0.0001 --warmup_epochs 10 --input_size 300 --experiment_name BS_Pytorch_EPOCHS  --eval --file_name "test"

# %%
# !ls /home/sebastian/codes/data/ABGQI_mel_spectrograms
# Out:
# merged	Pruebas_Rutas.csv  test  train	val
