# %%
data_path = "/Users/sebasmos/Documents/DATASETS/ESC-50-master/Mels_original_5_class"
csv_path = "/Users/sebasmos/Documents/DATASETS/ESC-50-master/meta/esc50.csv"
output_path = "/Users/sebasmos/Documents/VE_paper/data/ESC-50-master/Mels_HD"  # New output path for the folds

# %%
# !find /Users/sebasmos/Documents/DATASETS/ESC-50-master/Mels_original_5_class -type f | wc -l
# Out:
#     2000

# %%
# !ls /Users/sebasmos/Documents/DATASETS/ESC-50-master/Mels_original_5_class
# Out:
# AN EU HS ID NS

# %%
# !find /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/Mels_original_5_class -type f | wc -l
# Out:
# find: /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/Mels_original_5_class: No such file or directory
#        0

# %%
# !find /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/Mels_HD  -type f | wc -l
# Out:
#     2000

# %%
# %% bash
# chmod +x ./split_data.sh
#
# ./split_data.sh -s /Users/sebasmos/Documents/DATASETS/ESC-50-master/Mels_original_5_class -t /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/Mels_HD -r 90
# Out:
# UsageError: Cell magic `%%` not found.
