# %% [markdown]
# # 1. Quantized model

# %%
# !python quantized_inference.py \
    --data_path /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/esc50_efficientnet_b3_1536_bs64 \
    --total_num_seed 20 \
    --output_dir /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64 \
    --num_classes 7

# !python quantized_inference.py \
#     --data_path "/Users/sebasmos/Documents/VE_paper/data/urban8k_efficientnet_b3_PCA/efficientnet_b3_1536_bs64_PCA0.95" \
#     --total_num_seed 20 \
#     --output_dir "/Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_urban8k_efficientnet_b3_PCA"
# Out:
# SEED 0
# --------------------------------
# Val data: /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/esc50_efficientnet_b3_1536_bs64/val_embeddings.csv
# Error: Model file /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64/seed_0/best_model.pth not found.
# SEED 1
# --------------------------------
# Val data: /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/esc50_efficientnet_b3_1536_bs64/val_embeddings.csv
# Error: Model file /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64/seed_1/best_model.pth not found.
# SEED 2
# --------------------------------
# Val data: /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/esc50_efficientnet_b3_1536_bs64/val_embeddings.csv
# Error: Model file /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64/seed_2/best_model.pth not found.
# SEED 3
# --------------------------------
# Val data: /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/esc50_efficientnet_b3_1536_bs64/val_embeddings.csv
# Error: Model file /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64/seed_3/best_model.pth not found.
# SEED 4
# --------------------------------
# Val data: /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/esc50_efficientnet_b3_1536_bs64/val_embeddings.csv
# Error: Model file /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64/seed_4/best_model.pth not found.
# SEED 5
# --------------------------------
# Val data: /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/esc50_efficientnet_b3_1536_bs64/val_embeddings.csv
# Error: Model file /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64/seed_5/best_model.pth not found.
# SEED 6
# --------------------------------
# Val data: /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/esc50_efficientnet_b3_1536_bs64/val_embeddings.csv
# Error: Model file /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64/seed_6/best_model.pth not found.
# SEED 7
# --------------------------------
# Val data: /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/esc50_efficientnet_b3_1536_bs64/val_embeddings.csv
# Error: Model file /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64/seed_7/best_model.pth not found.
# SEED 8
# --------------------------------
# Val data: /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/esc50_efficientnet_b3_1536_bs64/val_embeddings.csv
# Error: Model file /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64/seed_8/best_model.pth not found.
# SEED 9
# --------------------------------
# Val data: /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/esc50_efficientnet_b3_1536_bs64/val_embeddings.csv
# Error: Model file /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64/seed_9/best_model.pth not found.
# SEED 10
# --------------------------------
# Val data: /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/esc50_efficientnet_b3_1536_bs64/val_embeddings.csv
# Error: Model file /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64/seed_10/best_model.pth not found.
# SEED 11
# --------------------------------
# Val data: /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/esc50_efficientnet_b3_1536_bs64/val_embeddings.csv
# Error: Model file /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64/seed_11/best_model.pth not found.
# SEED 12
# --------------------------------
# Val data: /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/esc50_efficientnet_b3_1536_bs64/val_embeddings.csv
# Error: Model file /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64/seed_12/best_model.pth not found.
# SEED 13
# --------------------------------
# Val data: /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/esc50_efficientnet_b3_1536_bs64/val_embeddings.csv
# Error: Model file /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64/seed_13/best_model.pth not found.
# SEED 14
# --------------------------------
# Val data: /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/esc50_efficientnet_b3_1536_bs64/val_embeddings.csv
# Error: Model file /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64/seed_14/best_model.pth not found.
# SEED 15
# --------------------------------
# Val data: /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/esc50_efficientnet_b3_1536_bs64/val_embeddings.csv
# Error: Model file /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64/seed_15/best_model.pth not found.
# SEED 16
# --------------------------------
# Val data: /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/esc50_efficientnet_b3_1536_bs64/val_embeddings.csv
# Error: Model file /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64/seed_16/best_model.pth not found.
# SEED 17
# --------------------------------
# Val data: /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/esc50_efficientnet_b3_1536_bs64/val_embeddings.csv
# Error: Model file /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64/seed_17/best_model.pth not found.
# SEED 18
# --------------------------------
# Val data: /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/esc50_efficientnet_b3_1536_bs64/val_embeddings.csv
# Error: Model file /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64/seed_18/best_model.pth not found.
# SEED 19
# --------------------------------
# Val data: /Users/sebasmos/Documents/VE_paper/data/ESC-50-master/esc50_efficientnet_b3_1536_bs64/val_embeddings.csv
# Error: Model file /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64/seed_19/best_model.pth not found.
# Metrics for seed 0 not found at /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64_quantized_model/seed_0. Skipping this seed.
# Metrics for seed 1 not found at /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64_quantized_model/seed_1. Skipping this seed.
# Metrics for seed 2 not found at /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64_quantized_model/seed_2. Skipping this seed.
# Metrics for seed 3 not found at /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64_quantized_model/seed_3. Skipping this seed.
# Metrics for seed 4 not found at /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64_quantized_model/seed_4. Skipping this seed.
# Metrics for seed 5 not found at /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64_quantized_model/seed_5. Skipping this seed.
# Metrics for seed 6 not found at /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64_quantized_model/seed_6. Skipping this seed.
# Metrics for seed 7 not found at /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64_quantized_model/seed_7. Skipping this seed.
# Metrics for seed 8 not found at /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64_quantized_model/seed_8. Skipping this seed.
# Metrics for seed 9 not found at /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64_quantized_model/seed_9. Skipping this seed.
# Metrics for seed 10 not found at /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64_quantized_model/seed_10. Skipping this seed.
# Metrics for seed 11 not found at /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64_quantized_model/seed_11. Skipping this seed.
# Metrics for seed 12 not found at /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64_quantized_model/seed_12. Skipping this seed.
# Metrics for seed 13 not found at /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64_quantized_model/seed_13. Skipping this seed.
# Metrics for seed 14 not found at /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64_quantized_model/seed_14. Skipping this seed.
# Metrics for seed 15 not found at /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64_quantized_model/seed_15. Skipping this seed.
# Metrics for seed 16 not found at /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64_quantized_model/seed_16. Skipping this seed.
# Metrics for seed 17 not found at /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64_quantized_model/seed_17. Skipping this seed.
# Metrics for seed 18 not found at /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64_quantized_model/seed_18. Skipping this seed.
# Metrics for seed 19 not found at /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64/mlp_esc50_efficientnet_b3_1536_bs64_quantized_model/seed_19. Skipping this seed.
# No metrics were found for any seed. Cannot calculate average metrics.
# Evaluation across different seeds completed. Results saved to the output directory.

# %%
# !python calc_qflops.py \
    --data_path /Users/sebasmos/Documents/VE_paper/0_VE_extraction/efficientnet_b3/efficientnet_b3_1536_bs64 \
    --seed_folder 0 \
    --num_classes 7 \
    --output_dir /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_ESC50_efficientnet_b3_1536_bs64 
# PCA
# !python calc_qflops.py \
#     --data_path "/Users/sebasmos/Documents/VE_paper/data/urban8k_efficientnet_b3_PCA/efficientnet_b3_1536_bs64_PCA0.95" \
#     --seed_folder 0 \
#     --num_classes 5 \
#     --output_dir "/Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_urban8k_efficientnet_b3_PCA"
# Out:
# Loading model from: /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_urban8k_efficientnet_b3_PCA/mlp_efficientnet_b3_1536_bs64_PCA0.95/seed_0/best_model.pth
# /Users/sebasmos/Documents/VE_paper/1_VE_experiments/part_2_quantized_model/calc_qflops.py:33: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=device))
# [W130 10:38:16.488700000 qlinear_dynamic.cpp:250] Warning: Currently, qnnpack incorrectly ignores reduce_range when it is set to true; this may change in a future release. (function operator())
#
# ------------------------------------- Calculate Flops Results -------------------------------------
# Notations:
# number of parameters (Params), number of multiply-accumulate operations(MACs),
# number of floating-point operations (FLOPs), floating-point operations per second (FLOPS),
# fwd FLOPs (model forward propagation FLOPs), bwd FLOPs (model backward propagation FLOPs),
# default model backpropagation takes 2.00 times as much computation as forward propagation.
#
# Total Training Params:                                                  0
# fwd MACs:                                                               0 MACs
# fwd FLOPs:                                                              2.693 KFLOPS
# fwd+bwd MACs:                                                           0 MACs
# fwd+bwd FLOPs:                                                          8.079 KFLOPS
#
# -------------------------------- Detailed Calculated FLOPs Results --------------------------------
# Each module caculated is listed after its name in the following order:
# params, percentage of total params, MACs, percentage of total MACs, FLOPS, percentage of total FLOPs
#
# Note: 1. A module can have torch.nn.module or torch.nn.functional to compute logits (e.g. CrossEntropyLoss).
#  They are not counted as submodules in calflops and not to be printed out. However they make up the difference between a parent's MACs and the sum of its submodules'.
# 2. Number of floating-point operations is a theoretical estimation, thus FLOPS computed using that could be larger than the maximum system throughput.
#
# SClassifier(
#   0 = 0% Params, 0 MACs = 0% MACs, 2.69 KFLOPS = 100% FLOPs
#   (fc_layers): Sequential(
#     0 = 0% Params, 0 MACs = 0% MACs, 2.69 KFLOPS = 99.8143% FLOPs
#     (0): DynamicQuantizedLinear(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, in_features=302, out_features=256, dtype=torch.qint8, qscheme=torch.per_tensor_affine)
#     (1): LayerNorm(0 = 0% Params, 0 MACs = 0% MACs, 1.28 KFLOPS = 47.5306% FLOPs, (256,), eps=1e-05, elementwise_affine=True)
#     (2): ReLU(0 = 0% Params, 0 MACs = 0% MACs, 256 FLOPS = 9.5061% FLOPs)
#     (3): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.3, inplace=False)
#     (4): DynamicQuantizedLinear(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, in_features=256, out_features=128, dtype=torch.qint8, qscheme=torch.per_tensor_affine)
#     (5): LayerNorm(0 = 0% Params, 0 MACs = 0% MACs, 640 FLOPS = 23.7653% FLOPs, (128,), eps=1e-05, elementwise_affine=True)
#     (6): ReLU(0 = 0% Params, 0 MACs = 0% MACs, 128 FLOPS = 4.7531% FLOPs)
#     (7): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.3, inplace=False)
#     (8): DynamicQuantizedLinear(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, in_features=128, out_features=64, dtype=torch.qint8, qscheme=torch.per_tensor_affine)
#     (9): LayerNorm(0 = 0% Params, 0 MACs = 0% MACs, 320 FLOPS = 11.8827% FLOPs, (64,), eps=1e-05, elementwise_affine=True)
#     (10): ReLU(0 = 0% Params, 0 MACs = 0% MACs, 64 FLOPS = 2.3765% FLOPs)
#     (11): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.3, inplace=False)
#   )
#   (output_layer): DynamicQuantizedLinear(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, in_features=64, out_features=5, dtype=torch.qint8, qscheme=torch.per_tensor_affine)
#   (activation_fn): ReLU(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#   (softmax): Softmax(0 = 0% Params, 0 MACs = 0% MACs, 5 FLOPS = 0.1857% FLOPs, dim=1)
# )
# ---------------------------------------------------------------------------------------------------
# {'KFLOPS': 2.693, 'KMACS': 0.0, 'KPARAMS': 0.0}
# Results saved to /Users/sebasmos/Documents/VE_paper/1_VE_experiments/results_urban8k_efficientnet_b3_PCA/mlp_efficientnet_b3_1536_bs64_PCA0.95/seed_0/flops_results.csv
#    KFLOPS  KMACS  KPARAMS
# 0   2.693    0.0      0.0
